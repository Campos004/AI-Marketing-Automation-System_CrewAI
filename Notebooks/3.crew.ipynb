# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm=LLM(
    model="cerebras/llama-3.3-70b",
    temperature=0.1
)

# %%
from crewai import Agent,Task,Crew

research_agent=Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic:{topic}",
    backstory="You are an expert at finding relevent and factual data.",
    verborse=True,
    llm=llm
)

writer_agent=Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the reasearch",
    backstory="You are skilled at writting engaging summaries based on provided content.",
    verborse=True,
    llm=llm
)

# %%
task1=Task(
    description="Find 3-5 interesting facts about the topic:{topic}",
    expected_output="A bullet list of 4-5 facts",
    agent=research_agent,
)

task2=Task(
    description="Write a 120 words blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary of 120 words",
    agent=writer_agent,
    context=[task1],
)

crew=Crew(
    agents=[research_agent,writer_agent],
    tasks=[task1,task2],
    verbose=True
)

crew.kickoff(inputs={"topic":"the future of electrical vechicles"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: ed983dc3-4f8d-41c0-9077-79842f8e4514                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting facts about the topic:the future of electrical vechicles                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  * By 2040, it's estimated that over 50% of new car sales will be electric vehicles (EVs), with many countries  │
# │  investing heavily in EV infrastructure and incentivizing consumers to make the switch.                         │
# │  * The future of electrical vehicles is expected to be shaped by advancements in battery technology, with       │
# │  solid-state batteries potentially offering faster charging times, longer ranges, and lower production costs,   │
# │  making EVs even more competitive with traditional gasoline-powered vehicles.                                   │
# │  * Electric vehicles are not just limited to cars, with many companies exploring the development of electric    │
# │  trucks, buses, and even airplanes, which could significantly reduce greenhouse gas emissions from the          │
# │  transportation sector and improve air quality in urban areas.                                                  │
# │  * The growth of electric vehicles is also driving innovation in charging technology, with the development of   │
# │  high-speed charging stations that can charge an EV to 80% in under 30 minutes, and wireless charging systems   │
# │  that could make charging as simple as pulling into a parking spot.                                             │
# │  * As the demand for electric vehicles continues to rise, there are concerns about the supply of critical       │
# │  materials like lithium, cobalt, and nickel, which are used in EV batteries, leading to a growing focus on      │
# │  recycling and sustainable sourcing of these materials to ensure a responsible and environmentally-friendly     │
# │  transition to an electric vehicle future.                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 58c05354-3daa-4677-a664-1586dacf207d                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electrical vehicles is poised for significant growth, with over 50% of new car sales expected    │
# │  to be electric by 2040. Advancements in battery technology, such as solid-state batteries, will drive this     │
# │  growth, offering faster charging times and longer ranges. Electric vehicles will extend beyond cars, with      │
# │  trucks, buses, and airplanes also being developed, reducing greenhouse gas emissions and improving air         │
# │  quality. Innovative charging technologies, including high-speed charging stations and wireless charging        │
# │  systems, will make charging easier and more convenient. As demand rises, sustainable sourcing and recycling    │
# │  of critical materials like lithium and cobalt will be crucial for a responsible transition to an electric      │
# │  vehicle future.                                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: c5b2371e-63d5-458b-9ee7-a387495b678f                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CrewOutput(raw='The future of electrical vehicles is poised for significant growth, with over 50% of new car sales expected to be electric by 2040. Advancements in battery technology, such as solid-state batteries, will drive this growth, offering faster charging times and longer ranges. Electric vehicles will extend beyond cars, with trucks, buses, and airplanes also being developed, reducing greenhouse gas emissions and improving air quality. Innovative charging technologies, including high-speed charging stations and wireless charging systems, will make charging easier and more convenient. As demand rises, sustainable sourcing and recycling of critical materials like lithium and cobalt will be crucial for a responsible transition to an electric vehicle future.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting facts about the topic:the future of electrical vechicles', name='Find 3-5 interesting facts about the topic:the future of electrical vechicles', expected_output='A bullet list of 4-5 facts', summary='Find 3-5 interesting facts about the topic:the future of electrical...', raw="* By 2040, it's estimated that over 50% of new car sales will be electric vehicles (EVs), with many countries investing heavily in EV infrastructure and incentivizing consumers to make the switch.\n* The future of electrical vehicles is expected to be shaped by advancements in battery technology, with solid-state batteries potentially offering faster charging times, longer ranges, and lower production costs, making EVs even more competitive with traditional gasoline-powered vehicles.\n* Electric vehicles are not just limited to cars, with many companies exploring the development of electric trucks, buses, and even airplanes, which could significantly reduce greenhouse gas emissions from the transportation sector and improve air quality in urban areas.\n* The growth of electric vehicles is also driving innovation in charging technology, with the development of high-speed charging stations that can charge an EV to 80% in under 30 minutes, and wireless charging systems that could make charging as simple as pulling into a parking spot.\n* As the demand for electric vehicles continues to rise, there are concerns about the supply of critical materials like lithium, cobalt, and nickel, which are used in EV batteries, leading to a growing focus on recycling and sustainable sourcing of these materials to ensure a responsible and environmentally-friendly transition to an electric vehicle future.", pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevent and factual data.\nYour personal goal is: Research interesting facts about the topic:the future of electrical vechicles\nTo give my best complete final answer to the task respond using the exact following format:\n\nThought: I now can give a great answer\nFinal Answer: Your final answer must be the great and the most complete as possible, it must be outcome described.\n\nI MUST use these formats, my job depends on it!'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting facts about the topic:the future of electrical vechicles\n\nThis is the expected criteria for your final answer: A bullet list of 4-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nBegin! This is VERY important to you, use the tools available and give your best Final Answer, your job depends on it!\n\nThought:'}, {'role': 'assistant', 'content': "I now can give a great answer\n\nFinal Answer: \n* By 2040, it's estimated that over 50% of new car sales will be electric vehicles (EVs), with many countries investing heavily in EV infrastructure and incentivizing consumers to make the switch.\n* The future of electrical vehicles is expected to be shaped by advancements in battery technology, with s ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: ed983dc3-4f8d-41c0-9077-79842f8e4514                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: The future of electrical vehicles is poised for significant growth, with over 50% of new car     │
# │  sales expected to be electric by 2040. Advancements in battery technology, such as solid-state batteries,      │
# │  will drive this growth, offering faster charging times and longer ranges. Electric vehicles will extend        │
# │  beyond cars, with trucks, buses, and airplanes also being developed, reducing greenhouse gas emissions and     │
# │  improving air quality. Innovative charging technologies, including high-speed charging stations and wireless   │
# │  charging systems, will make charging easier and more convenient. As demand rises, sustainable sourcing and     │
# │  recycling of critical materials like lithium and cobalt will be crucial for a responsible transition to an     │
# │  electric vehicle future.                                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
